# %% [markdown]
# <a href="https://colab.research.google.com/github/karrichandu31-png/python_programs_colab/blob/main/Conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Positive, Negative, or Zero

num = int(input("Enter number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter number: 5
# Positive

# %%
# 2. Even or Odd

num = int(input("Enter number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number: 5
# Odd

# %%
# 3. Voting Eligibility

age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Enter age: 18
# Eligible to vote

# %%
# 4. Pass or Fail

marks = int(input("Enter marks: "))

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks: 99
# Pass

# %%
# 5. Largest of Two Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Largest =", a)
else:
    print("Largest =", b)
# Out:
# Enter first number: 10
# Enter second number: 50
# Largest = 50

# %%
# 6. Smallest of Two Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a < b:
    print("Smallest =", a)
else:
    print("Smallest =", b)
# Out:
# Enter first number: 10
# Enter second number: 20
# Smallest = 10

# %%
# 7. Divisible by 5

num = int(input("Enter number: "))

if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter number: 5
# Divisible by 5

# %%
# 8. Divisible by 5 and 3

num = int(input("Enter number: "))

if num % 5 == 0 and num % 3 == 0:
    print("Divisible by 5 and 3")
else:
    print("Not divisible by 5 and 3")
# Out:
# Enter number: 15
# Divisible by 5 and 3

# %%
# 9. Multiple of 2 or 7

num = int(input("Enter number: "))

if num % 2 == 0 or num % 7 == 0:
    print("Multiple of 2 or 7")
else:
    print("Not multiple of 2 or 7")
# Out:
# Enter number: 2
# Multiple of 2 or 7

# %%
# 10. Number Between Range

num = int(input("Enter number: "))

if 1 <= num <= 100:
    print("Number is between 1 and 100")
else:
    print("Out of range")
# Out:
# Enter number: 99
# Number is between 1 and 100

# %%
# 11. Largest of Three Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest =", a)
elif b > c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter first number: 10
# Enter second number: 15
# Enter third number: 20
# Largest = 20

# %%
# 12. Grade Calculator

marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 99
# Grade A

# %%
# 13. Leap Year Checker

year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter year: 2026
# Not Leap Year

# %%
# 14. Character Checker

ch = input("Enter character: ")

if ch.isalpha():
    print("Alphabet")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter character: a
# Alphabet

# %%
# 15. Vowel or Consonant

ch = input("Enter character: ")

if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter character: a
# Vowel

# %%
# 16. Simple Calculator

a = int(input("Enter first number: "))
op = input("Enter operator: ")
b = int(input("Enter second number: "))

if op == "+":
    print("Result =", a + b)

elif op == "-":
    print("Result =", a - b)

elif op == "*":
    print("Result =", a * b)

elif op == "/":
    print("Result =", a / b)

else:
    print("Invalid Operator")
# Out:
# Enter first number: 4
# Enter operator: +
# Enter second number: 5
# Result = 9

# %%
# 17. ATM PIN Verification

pin = int(input("Enter PIN: "))

if pin == 1234:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter PIN: 1234
# Access Granted

# %%
# 18. Username and Password Validation

username = input("Enter username: ")
password = input("Enter password: ")

if username == "chandu" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: chandu
# Enter password: 1234
# Login Successful

# %%
# 19. Temperature Checker

temp = int(input("Enter temperature: "))

if temp >= 35:
    print("Hot")
elif temp >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature: 50
# Hot

# %%
# 20. Movie Ticket Eligibility

age = int(input("Enter age: "))

if age >= 18:
    print("Movie Entry Allowed")
else:
    print("Access Denied")
# Out:
# Enter age: 18
# Movie Entry Allowed
